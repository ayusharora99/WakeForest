# %%
import pandas as pd

# %%
data = pd.read_csv('Pitch_by_Pitch.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49772 entries, 0 to 49771
# Data columns (total 67 columns):
# PitchNo                49772 non-null int64
# PAofInning             49772 non-null int64
# PitchofPA              49772 non-null int64
# Pitcher                49771 non-null object
# PitcherId              49771 non-null float64
# PitcherThrows          49772 non-null object
# PitcherTeam            49772 non-null object
# Batter                 49771 non-null object
# BatterId               49771 non-null float64
# BatterSide             49772 non-null object
# BatterTeam             49772 non-null object
# PitcherSet             49772 non-null object
# Inning                 49772 non-null int64
# Outs                   49772 non-null int64
# Balls                  49772 non-null int64
# Strikes                49772 non-null int64
# TaggedPitchType        49772 non-null object
# AutoPitchType          49772 non-null object
# ...

# %%
college = pd.read_csv('Louisville2020Data.csv')

# %%
college.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3613 entries, 0 to 3612
# Data columns (total 75 columns):
# PitchNo                3613 non-null int64
# Date                   3613 non-null object
# Time                   3613 non-null object
# PAofInning             3613 non-null int64
# PitchofPA              3613 non-null int64
# Pitcher                3613 non-null object
# PitcherId              3613 non-null int64
# PitcherThrows          3613 non-null object
# PitcherTeam            3613 non-null object
# Batter                 3613 non-null object
# BatterId               3613 non-null int64
# BatterSide             3613 non-null object
# BatterTeam             3613 non-null object
# PitcherSet             3613 non-null object
# Inning                 3613 non-null int64
# Top/Bottom             3613 non-null object
# Outs                   3613 non-null int64
# Balls                  3613 non-null int64
# Strikes                3613 non-null int64
# ...

# %%
combined = pd.concat([data, college], axis=0)
# Out:
# /Users/ayusharora/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 53385 entries, 0 to 3612
# Data columns (total 75 columns):
# Angle                  12164 non-null float64
# AutoPitchType          53385 non-null object
# AwayTeam               53385 non-null object
# Balls                  53385 non-null int64
# Batter                 53384 non-null object
# BatterId               53384 non-null float64
# BatterSide             53385 non-null object
# BatterTeam             53385 non-null object
# Bearing                11502 non-null float64
# Date                   3613 non-null object
# Direction              12164 non-null float64
# Distance               11502 non-null float64
# ExitSpeed              12164 non-null float64
# Extension              52932 non-null float64
# GameID                 3613 non-null object
# HangTime               11502 non-null float64
# HitSpinRate            8189 non-null float64
# HitType                53385 non-null object
# ...

# %%
combined.to_csv('combined.csv')

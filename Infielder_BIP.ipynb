# %%
import pandas as pd

# %%
data = pd.read_csv('BIP_numerical_NA.csv')

# %%
data.head()
# Out:
#    Unnamed: 0  PitchNo  PAofInning  PitchofPA  PitcherId   BatterId  Inning  \
# 0           0       31           4          4  8886490.0  8889935.0       1
# 1           1       53           3          1  8889942.0  8886477.0       2
# 2           2       63           1          1  8886490.0  8889937.0       2
# 3           3       93           7          2  8889947.0  8886477.0       3
# 4           4      128           4          3  8889947.0  8881734.0       4
#
#    Outs  Balls  Strikes  ...        x0    y0        z0       vx0         vy0  \
# 0     1      2        1  ... -0.910257  50.0  5.132413  1.918590 -124.614626
# 1     1      0        0  ... -0.813253  50.0  5.902546  4.365727 -126.052743
# 2     1      0        0  ... -0.441719  50.0  5.333961  4.862950 -131.897976
# 3     2      1        0  ... -2.193309  50.0  5.480263  5.652254 -130.319387
# 4     2      1        1  ... -2.142848  50.0  5.527071  4.224837 -115.353692
#
# ...

# %%
data = data.drop(columns = 'Unnamed: 0')

# %%
data.head()
# Out:
#    PitchNo  PAofInning  PitchofPA  PitcherId   BatterId  Inning  Outs  Balls  \
# 0       31           4          4  8886490.0  8889935.0       1     1      2
# 1       53           3          1  8889942.0  8886477.0       2     1      0
# 2       63           1          1  8886490.0  8889937.0       2     1      0
# 3       93           7          2  8889947.0  8886477.0       3     2      1
# 4      128           4          3  8889947.0  8881734.0       4     2      1
#
#    Strikes  OutsOnPlay  ...        x0    y0        z0       vx0         vy0  \
# 0        1           0  ... -0.910257  50.0  5.132413  1.918590 -124.614626
# 1        0           0  ... -0.813253  50.0  5.902546  4.365727 -126.052743
# 2        0           1  ... -0.441719  50.0  5.333961  4.862950 -131.897976
# 3        0           0  ... -2.193309  50.0  5.480263  5.652254 -130.319387
# 4        1           1  ... -2.142848  50.0  5.527071  4.224837 -115.353692
#
# ...

# %%
data = data[data['Angle']<=5]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35 entries, 58 to 3802
# Data columns (total 51 columns):
# PitchNo                35 non-null int64
# PAofInning             35 non-null int64
# PitchofPA              35 non-null int64
# PitcherId              35 non-null float64
# BatterId               35 non-null float64
# Inning                 35 non-null int64
# Outs                   35 non-null int64
# Balls                  35 non-null int64
# Strikes                35 non-null int64
# OutsOnPlay             35 non-null int64
# RunsScored             35 non-null int64
# RelSpeed               35 non-null float64
# VertRelAngle           35 non-null float64
# HorzRelAngle           35 non-null float64
# SpinRate               35 non-null float64
# SpinAxis               35 non-null float64
# RelHeight              35 non-null float64
# RelSide                35 non-null float64
# Extension              35 non-null float64
# VertBreak              35 non-null float64
# ...
